# %%
import matplotlib.pyplot as plt
import scipy.sparse.linalg as ssl
import numpy as np

from wifi_matrix import generate_A_higher_order, parse_image, pad_image

# %%
wavelength = 0.06  # Wavelength of WiFi in meters: 0.12 for 2.5GHz; 0.06 for 5GHz.
k = 2 * np.pi / wavelength
n_air = 1
# n_concrete = 2.16 - 0.021j  # Should depend on wavenumber.
n_concrete = 2.5 - 1.0j * (
        2.5 * 0.2
    )

img = parse_image("testrom5.png", n_air, n_concrete)

# %%
# %time A = generate_A_higher_order(img, k)
# Out:
# Wall time: 11.4 s

# %%
arr = A[500000-50 : 500000+50, 500000-50:500000+50].toarrayrray()

# %%
plt.figure(figsize = (15,15))
plt.imshow(np.log(np.abs(arr[:50,:50])))
# Out:
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
