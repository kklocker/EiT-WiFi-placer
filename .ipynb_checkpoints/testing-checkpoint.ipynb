# %%
# %load_ext autoreload
# %autoreload
import cv2
import matplotlib.pyplot as plt
path = "testrom.png"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pic = cv2.imread(path, 0)

# %%
pic = (pic - 255) % 255

# %%
plt.imshow(pic)

# %%
import numpy as np

# %%
A = np.array([[0, 1,0], [1, 4,1],[0,1,0]])
b = np.array([[0, 0], [0, 0]])

# %%
x = np.linalg.solve(A, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-1c1a7cd0e784> in <module>
# ----> 1 x = np.linalg.solve(A, b)
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~\Anaconda3\envs\numfys\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     402     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 403     r = gufunc(a, b, signature=signature, extobj=extobj)
#     404
#     405     return wrap(r.astype(result_t, copy=False))
#
# ValueError: solve: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (m,m),(m,n)->(m,n) (size 2 is different from 3)

# %%
x
# Out:
# array([[-1., -1.],
#        [ 1.,  3.]])

# %%
np.dot(A, x)
# Out:
# array([[1., 5.],
#        [1., 9.]])

# %%
import scipy

# %%
arr = np.ones((1000,1000))

# %%
lap = [[0.25, 0.5, 0.25],[0.5,-3,0.5],[0.25,0.5,0.25]]

# %%
from scipy import signal

# %%
test_conv = signal.convolve(arr, lap)

# %%
test_conv.shape
# Out:
# (1002, 1002)

# %%
B = np.ones_like(test_conv)

# %%
B[623:633, 193:203] = 100

# %%
sol = np.linalg.solve(test_conv, B)

# %%
plt.imshow(B)
plt.colorbar()

# %%
fig = plt.figure(figsize=(16, 16))
p = plt.imshow(test_conv)

# %%
plt.imshow(np.abs(sol))

# %%
np.abs(sol)
# Out:
# array([[1.13045035e+13, 1.13045035e+13, 1.13045035e+13, ...,
#         1.13045035e+13, 1.13045035e+13, 1.13045035e+13],
#        [3.04341653e+12, 3.04341653e+12, 3.04341653e+12, ...,
#         3.04341653e+12, 3.04341653e+12, 3.04341653e+12],
#        [2.95321022e+14, 2.95321022e+14, 2.95321022e+14, ...,
#         2.95321022e+14, 2.95321022e+14, 2.95321022e+14],
#        ...,
#        [2.88513179e+14, 2.88513179e+14, 2.88513179e+14, ...,
#         2.88513179e+14, 2.88513179e+14, 2.88513179e+14],
#        [8.07260634e+12, 8.07260634e+12, 8.07260634e+12, ...,
#         8.07260634e+12, 8.07260634e+12, 8.07260634e+12],
#        [1.88480628e+11, 1.88480628e+11, 1.88480628e+11, ...,
#         1.88480628e+11, 1.88480628e+11, 1.88480628e+11]])

# %%
b.shape
# Out:
# (1002, 1002)

# %% [markdown]
# # Teste scorefunksjoner

# %%
N = 10000
def gauss_(N = 1000, sigma=1.0, mu=0):
    x, y = np.meshgrid(np.linspace(-1,1,N), np.linspace(-1,1,N))
    d = np.sqrt(x*x+y*y)
    return np.exp(-( (d-mu)**2 / ( 2.0 * sigma**2 ) ) )

# %%
plt.imshow(g)

# %%
p = (np.random.randint(0,N-1), np.random.randint(0,N-1))

# %%
# %timeit score_step(g)
# Out:
# 140 ms ± 1.34 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-faceeedfc40a> in <module>
#       1 get_ipython().run_line_magic('timeit', 'score_step(g)')
# ----> 2 get_ipython().run_line_magic('timeit', 'weighted_score(g,p)')
#
# ~\Anaconda3\envs\numfys\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~\Anaconda3\envs\numfys\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\envs\numfys\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1158             for index in range(0, 10):
#    1159                 number = 10 ** index
# -> 1160                 time_number = timer.timeit(number)
#    1161                 if time_number >= 0.2:
#    1162                     break
#
# ~\Anaconda3\envs\numfys\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# ~\Anaconda3\envs\numfys\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2480                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2481             else:
# -> 2482                 sqnorm = dot(x, x)
#    2483             ret = sqrt(sqnorm)
#    2484             if keepdims:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from score import *

# %%
g_2 = gauss_(1000)

# %%
# %time weighted_score(g_2,p)
# %time score_step(g_2)
# Out:
# Wall time: 19 s
# Wall time: 4 ms
# 0.7316665544817711

# %%
g_ = create_gaussian(100)

# %%
weighted_score(g_,p,1.2)
# Out:
# C:\Users\KarlKristian\Projects\EiT\score.py:20: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "weighted_score" failed type inference due to: Invalid use of Function(<function norm at 0x00000180071D88B8>) with argument(s) of type(s): (list(int64))
#  * parameterized
# In definition 0:
#     TypingError: np.linalg.norm() only supported for array types
#     raised from C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\targets\linalg.py:841
# In definition 1:
#     TypingError: np.linalg.norm() only supported for array types
#     raised from C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\targets\linalg.py:841
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<function norm at 0x00000180071D88B8>)
# [2] During: typing of call at C:\Users\KarlKristian\Projects\EiT\score.py (30)
#
#
# File "score.py", line 30:
# def weighted_score(u, p):
#     <source elided>
#
#      ^
#
#   temp = np.zeros_like(u)
# C:\Users\KarlKristian\Projects\EiT\score.py:20: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "weighted_score" failed type inference due to: cannot determine Numba type of <class 'numba.dispatcher.LiftedLoop'>
#
# File "score.py", line 28:
# def weighted_score(u, p):
#     <source elided>
#
#     return np.sum(temp) / A
#     ^
#
#   temp = np.zeros_like(u)
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "weighted_score" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "score.py", line 20:
# def weighted_score(u, p):
#     <source elided>
#     """
#     temp = np.zeros_like(u)
#     ^
#
#   state.func_ir.loc))
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "score.py", line 20:
# def weighted_score(u, p):
#     <source elided>
#     """
#     temp = np.zeros_like(u)
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\KarlKristian\Projects\EiT\score.py:20: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "weighted_score" failed type inference due to: Invalid use of Function(<function norm at 0x00000180071D88B8>) with argument(s) of type(s): (list(int64))
#  * parameterized
# In definition 0:
#     TypingError: np.linalg.norm() only supported for array types
#     raised from C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\targets\linalg.py:841
# In definition 1:
#     TypingError: np.linalg.norm() only supported for array types
#     raised from C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\targets\linalg.py:841
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<function norm at 0x00000180071D88B8>)
# [2] During: typing of call at C:\Users\KarlKristian\Projects\EiT\score.py (30)
#
#
# File "score.py", line 30:
# def weighted_score(u, p):
#     <source elided>
#
#      ^
#
#   temp = np.zeros_like(u)
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "weighted_score" was compiled in object mode without forceobj=True.
#
# File "score.py", line 28:
# def weighted_score(u, p):
#     <source elided>
#
#     return np.sum(temp) / A
#     ^
#
#   state.func_ir.loc))
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "score.py", line 28:
# def weighted_score(u, p):
#     <source elided>
#
#     return np.sum(temp) / A
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# 13045.369700783913
